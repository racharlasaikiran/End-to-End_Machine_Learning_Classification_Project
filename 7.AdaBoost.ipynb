# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
pd.set_option('display.max_columns',None)

# %%
x_train = pd.read_csv('x_train_data.csv')
x_test = pd.read_csv('x_test_data.csv')

# %%
y_train = pd.read_csv('y_train_data.csv')
y_test = pd.read_csv('y_test_data.csv')

# %%
from sklearn.decomposition import PCA
pc = PCA(n_components=0.95)
x_train=pc.fit_transform(x_train)
x_test = pc.transform(x_test)

# %%
pc.explained_variance_ratio_ *100
# Out:
# array([67.99319329, 10.80040851,  3.21988247,  1.62888885,  1.35056976,
#         1.32689937,  1.31950644,  1.31273071,  1.27063958,  1.25088137,
#         1.17674926,  0.87020472,  0.73264746,  0.60390463,  0.60224785])

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
estimator=AdaBoostClassifier()
param_grid={'n_estimators' : list(range(1,10))}
gscv=GridSearchCV(estimator,param_grid,cv=5,scoring='accuracy')
gscv.fit(x_train,y_train)
print(gscv.best_estimator_)
# Out:
# AdaBoostClassifier(n_estimators=7)

# %%
importances = model.feature_importances_
print(importances)
# Out:
# [0.         0.         0.28571429 0.         0.         0.14285714
#  0.         0.         0.         0.         0.14285714 0.
#  0.         0.28571429 0.14285714]

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
#modeling
model = AdaBoostClassifier(n_estimators = 7)
model.fit(x_train,y_train)

#predection
x_train_pred = model.predict(x_train)
x_test_pred = model.predict(x_test)

#evolution
print('train accuracy :', accuracy_score(y_train, x_train_pred))
print('test accuracy :', accuracy_score(y_test, x_test_pred))
from sklearn.model_selection import cross_val_score
print('cv score :',cross_val_score(model,x_train,y_train,cv=5,scoring='accuracy').mean())
# Out:
# train accuracy : 0.843875
# test accuracy : 0.833
# cv score : 0.842875

# %%
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)

# %%
x_train
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.914799  0.528205  2.039461  1.542103  1.050181  1.054567  0.583482
# 1     6.102245 -2.451125  0.058831 -0.591514 -0.861515 -1.326697  0.893408
# 2    -5.901076 -2.491076  2.340027  0.357953 -0.680079  0.514274 -0.074604
# 3    -7.923267  2.495652  2.536390 -0.648902 -0.219376  0.356058 -0.111425
# 4     8.074921  4.544926 -1.000699 -0.402255  1.639649 -0.402218 -0.497926
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  9.080035  3.541084 -1.496494  0.331089 -2.943954 -0.602662 -0.212498
# 7996 -5.912780  1.480738 -1.107300 -1.720868 -2.025411 -0.493141 -0.327400
# 7997  6.078030  3.550623  2.869060  0.612881  2.557880  1.226443 -0.987277
# 7998  9.072982  4.552478 -0.736215 -1.392322 -0.120635 -0.550617 -1.423795
# 7999 -7.904244 -0.528073 -1.197014  1.460958 -1.295048 -0.461939  1.042868
#
#             7         8         9         10        11        12        13  \
# 0    -1.603595  0.746762  0.757970 -1.615725 -1.069714 -0.822696  0.275707
# 1     1.383758 -0.274386  0.181449 -1.125002 -1.024087  1.172868 -1.149493
# 2     0.830236  0.258733  0.899582 -0.656222 -1.066285 -0.810458  0.107640
# 3     0.372277 -1.258411 -0.788729 -1.071575  1.031689  0.211887  0.474836
# 4     0.203312 -0.715092  0.271059  0.045804 -0.016390 -0.851550  0.552229
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  0.867772 -0.837832 -0.853879 -0.524326 -0.895457  1.155479  1.022939
# 7996  0.511775 -1.008475 -0.745628 -0.547760 -0.043438 -0.735171 -1.347643
# 7997  0.353443 -0.570029 -0.335762  0.107045 -0.851160  0.204278 -0.039826
# 7998 -0.495718 -0.286046  1.007238  0.648607 -0.036932 -0.764848  0.707553
# 7999 -0.500060 -0.017086  0.148744  0.222619 -0.060778 -0.908667 -0.740171
#
#             14
# 0    -0.773410
# 1    -0.108317
# 2    -0.930210
# 3     0.192481
# 4    -0.686510
# ...        ...
# 7995 -0.854225
# 7996 -0.021109
# 7997  0.916734
# 7998 -0.734738
# 7999 -0.457528
#
# [8000 rows x 15 columns]

# %%
x_train.drop(columns=[0,1,3,4,6,7,8,9,11,12],inplace=True)

# %%
x_test.drop(columns=[0,1,3,4,6,7,8,9,11,12],inplace=True)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
#modeling
model = AdaBoostClassifier(n_estimators = 7)
model.fit(x_train,y_train)

#predection
x_train_pred = model.predict(x_train)
x_test_pred = model.predict(x_test)

#evolution
print('train accuracy :', accuracy_score(y_train, x_train_pred))
print('test accuracy :', accuracy_score(y_test, x_test_pred))
from sklearn.model_selection import cross_val_score
print('cv score :',cross_val_score(model,x_train,y_train,cv=5,scoring='accuracy').mean())
# Out:
# train accuracy : 0.843875
# test accuracy : 0.833
# cv score : 0.842875
